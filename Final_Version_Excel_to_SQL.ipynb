# %% [markdown]
# # Финальные версиии, Final versions

# %%
import numpy as np
import psycopg2
from psycopg2 import Error
import pandas as pd

data = pd.read_csv('main_netflix.csv', sep = ';', encoding= 'unicode_escape')
print(data.show_id[1])

try:
    # Connect to an existing database
    connection = psycopg2.connect(user="postgres",
                                  password="user123",
                                  host="localhost",
                                  port="5433",
                                  database="db")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")
    # Dropping table iris if exists
    cursor.execute("DROP TABLE IF EXISTS films") 
    sql = '''CREATE TABLE films(
        show_id      varchar(255) primary key,
        title        varchar(255) not null,
        release_year varchar(255) not null,
        rating       varchar(255) not null,
        duration     varchar(255) not null
        )'''    
    # Creating a table
    cursor.execute(sql)
    connection.commit()
    print("table is created successfully")
    #for row in data:
        #print(row)
        #for i in row:
           #print(row)
            #print(data[row])
            
            #data_main = [[], []]
            #print(data[row])
            
    for i in range(7787):
        query = """INSERT INTO films VALUES (%s, %s, %s, %s, %s)""" 
        records = (data.show_id[i], data.title[i], data.release_year[i], data.rating[i], data.duration[i])
        cursor.execute(query, records)
        connection.commit()
    # Closing
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")

import numpy
from psycopg2.extensions import register_adapter, AsIs
def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)
def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)
register_adapter(numpy.float64, addapt_numpy_float64)
register_adapter(numpy.int64, addapt_numpy_int64)
# Out:
# s2
# PostgreSQL server information
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'db', 'host': 'localhost', 'port': '5433', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 13.3, compiled by Visual C++ build 1914, 64-bit',)
#
# table is created successfully
# PostgreSQL connection is closed

# %%
import numpy as np
import psycopg2
from psycopg2 import Error
import pandas as pd

model = pd.read_csv('boston.csv', sep = ';', encoding= 'unicode_escape')

try:
    # Connect to an existing database
    connection = psycopg2.connect(user="postgres",
                                  password="user123",
                                  host="localhost",
                                  port="5433",
                                  database="db")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")
    # Dropping table iris if exists
    cursor.execute("DROP TABLE IF EXISTS boston") 
    sql = '''CREATE TABLE boston(
    crim decimal(12) not null,
    zn decimal(12) not null,
    indus decimal(12) not null,
    chas decimal(12) not null,
    nox decimal(12) not null,
    rm decimal(12) not null,
    age decimal(12) not null,
    dis decimal(12) not null,
    rad decimal(12) not null,
    tax decimal(12) not null,
    ptratio decimal(12) not null,
    black decimal(12) not null,
    lstat decimal(12) not null,
    medv decimal(12) not null
)'''    
    # Creating a table
    cursor.execute(sql)
    connection.commit()
    print("table is created successfully")
    #for row in data:
        #print(row)
        #for i in row:
           #print(row)
            #print(data[row])
            
            #data_main = [[], []]
            #print(data[row])
            
    for i in range(506):
        query = """INSERT INTO boston VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""" 
        records = (model.crim[i], model.zn[i], model.indus[i], model.chas[i], model.nox[i], model.rm[i], model.age[i], model.dis[i], model.rad[i], model.tax[i], model.ptratio[i], model.black[i], model.lstat[i], model.medv[i])
        cursor.execute(query, records)
        connection.commit()
    # Closing
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'db', 'host': 'localhost', 'port': '5433', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 13.3, compiled by Visual C++ build 1914, 64-bit',)
#
# table is created successfully
# Error while connecting to PostgreSQL 'DataFrame' object has no attribute 'crim'
# PostgreSQL connection is closed

# %%
data.head()

# %%
import numpy as np
import psycopg2
from psycopg2 import Error
import pandas as pd

data = pd.read_csv('main.csv', sep = ';', encoding= 'unicode_escape')
print(data[::5])

try:
    # Connect to an existing database
    connection = psycopg2.connect(user="postgres",
                                  password="user123",
                                  host="localhost",
                                  port="5433",
                                  database="db")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")
    # Dropping table iris if exists
    cursor.execute("DROP TABLE IF EXISTS records") 
    sql = '''CREATE TABLE records(
        id decimal(32) primary key,
        score varchar(96) not null,
        name varchar(96) not null
        )'''    
    # Creating a table
    cursor.execute(sql)
    connection.commit()
    print("table is created successfully")
    for i in range(9):
        query = """INSERT INTO records VALUES (%s, %s, %s)""" 
        records = (data.id[i], data.score[i], data.name[i])
        cursor.execute(query, records)
        connection.commit()
    # Closing
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")

        
import numpy
from psycopg2.extensions import register_adapter, AsIs
def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)
def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)
register_adapter(numpy.float64, addapt_numpy_float64)
register_adapter(numpy.int64, addapt_numpy_int64)
# Out:
#    id  score  name
# 0   0   80.0    Ai
# 5   5   80.5  Yeni
# PostgreSQL server information
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'db', 'host': 'localhost', 'port': '5433', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 13.3, compiled by Visual C++ build 1914, 64-bit',)
#
# table is created successfully
# PostgreSQL connection is closed

# %%
data_two = pd.read_csv('main.csv', sep = ';', encoding= 'unicode_escape')
data_two
